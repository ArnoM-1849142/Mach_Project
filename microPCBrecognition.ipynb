# %% [markdown]
# # Machine learning project
#
# ## Introduction
#
# In this project, an implementation of the backpropagation algorithm for neural networks is made and applied to the task of [`micro_PCB`](https://www.kaggle.com/frettapper/micropcb-images) recognition. This project is made for the machine learning course [`Machine learning`](https://uhintra03.uhasselt.be/studiegidswww/opleidingsonderdeel.aspx?a=2021&i=4483&n=4&t=04) given at the joint training of kuleuven and uhasselt. The authors of this project are Molenaers Arno and Purnal Lennert.
#
#
# The libraries that need to be imported for this project are the following:
# - [`numpy`](http://www.numpy.org/) for all arrays and matrix operations.
# - [`matplotlib`](https://matplotlib.org/) for plotting.
# - [`scipy`](https://docs.scipy.org/doc/scipy/reference/) for scientific and numerical computation functions and tools.
# - [`csv`](https://docs.python.org/3/library/csv.html) for importing the image data
# - [`utils`]() utilities from exercise 4 from the coursera machine learning course
# - [`math`](https://docs.python.org/3/library/math.html) math library used for functions like square root

# %%
# used for manipulating directory paths
import os

# Scientific and vector computation for python
import numpy as np

# math library 
import math

# Plotting library
from matplotlib import pyplot

# Optimization module in scipy
from scipy import optimize

# Used for imorting csv data
import csv

# utilies library from the exercises of the machine learning course
import utils

# custom made functions for this Machine Learning dataset
import customUtils as cu

#used for timing the optimizations
from timeit import default_timer as timer 

# tells matplotlib to embed plots within the notebook
# %matplotlib inline

# used for importing/exporting matlab data
from scipy.io import savemat
from scipy.io import loadmat

# %% [markdown]
# ## importing the training data
# the training data is imported from a csv file. The X matrix contains the input features as a '6500x7500' matrix. y is a matrix containing the labels, for the neural network each label is encoded as a 13 dimensional vector with a 1 at the corresponding correct label and the other elements set to 0, making y a '6500x13' vector.
# > do not forget to specify the correct path to the csv file and to set the size of the imported data as well as the resolution of the images

# %%
X, y = cu.importImageDataFromCSV('../channeldata/channeldata50x50train.csv', data_size=6500)
# matlab function
#X, y = importImageTrainDataFromMatlab('dataset.mat', data_size=6500)

# %%
X_test, y_test = cu.importImageDataFromCSV('../channeldata/channeldata50x50test.csv', data_size=1625)
# matlab function
#X_test, y_test = importImageTestDataFromMatlab('dataset.mat', data_size=1625)

# %% [markdown]
# ## cost function
# The cost funtion used is as follows:
#
# $$ J(\theta) = \frac{1}{m} \sum_{i=1}^{m}\sum_{k=1}^{K} \left[ - y_k^{(i)} \log \left( \left( h_\theta \left( x^{(i)} \right) \right)_k \right) - \left( 1 - y_k^{(i)} \right) \log \left( 1 - \left( h_\theta \left( x^{(i)} \right) \right)_k \right) \right] + \frac{\lambda}{2 m} \left[ \sum_{j=1}^{sl+1} \sum_{k=1}^{sl} \left( \Theta_{j,k}^{(1)} \right)^2 + \sum_{j=1}^{sl+1} \sum_{k=1}^{sl} \left( \Theta_{j,k}^{(2)} \right)^2 \right] $$

# %% [markdown]
# ## initializing the theta parameters and hyperparameters
# The theta parameters must be initialized in a random way to avoid symmetry.
#
# In the random initialize function the following value for epsilon is used:
#
# $$\epsilon_{init} = \frac{\sqrt{6}}{\sqrt{L_{in} + L_{out}}}$$

# %%
num_layers = 3
input_layer_size = X.shape[1]
hidden_layer_size = 10000
num_labels = y.shape[1]

#choose a lambda
lambda_ = 0

# %%
eps1 = math.sqrt(6)/math.sqrt(input_layer_size + hidden_layer_size)
eps2 = math.sqrt(6)/math.sqrt(hidden_layer_size + num_labels)
print('epsilon init 1 = ' + str(eps1))
print('epsilon init 2 = ' + str(eps2))

initial_Theta1 = cu.randInitializeWeights(input_layer_size, hidden_layer_size, eps1)
initial_Theta2 = cu.randInitializeWeights(hidden_layer_size, num_labels, eps2)

initial_nn_params = np.concatenate([initial_Theta1.ravel(), initial_Theta2.ravel()], axis=0)
# Out:
# epsilon init 1 = 0.018516401995451025
# epsilon init 2 = 0.02447899125134676

# %% [markdown]
# ## learing the parameters with `scipy.optimize.minimize`
# next we will use the scipy.optimize.minimize function to minimize the randomly initialized parameters.

# %%
# we initialize the minimize function options
options = {'maxiter':50, 'disp':True}

#creating a lambda function for the cost function
costFunction = lambda p: cu.nnCostFunction(p, input_layer_size,
                                        hidden_layer_size,
                                        num_labels, X, y, lambda_)

# execute the optimization function
res = optimize.minimize(costFunction,
                        initial_nn_params,
                        jac=True,
                        method='TNC',
                        options=options)

# get the solution parameters
nn_params = res.x

#reshape nn_params to retrieve the seperate theta matrixes 
Theta1, Theta2 = cu.retrieveThetas(nn_params, input_layer_size, hidden_layer_size, num_labels)

# %%
#retrieve the theta's from nn_params
Theta1, Theta2 = cu.retrieveThetas(nn_params, input_layer_size, hidden_layer_size, num_labels)

# %% [markdown]
# ## checking the cost function and the gradients
# next we will verify the outcome of the cost function

# %%
J, grads = cu.nnCostFunction(nn_params, input_layer_size, hidden_layer_size,
                      num_labels, X, y, lambda_)

print('Cost at parameters: %.6f' % J)
# Out:
# Cost at parameters: 2.774604

# %% [markdown]
# ## try the trained neural network on the training data
# the trained parameters are used to recognize the `micro PCB` in the images from the training data itself. This is a first test to check if the trained parameters can be correct. To get an actual idea of the accuracy of the neural network, check te next segment where the same predictions are done on the test data.

# %%
pred = utils.predict(Theta1, Theta2, X)
y_vec = np.zeros(y.shape[0])


for j in range(0,y.shape[0]):
    y_vec[j] = np.where(y[j,:] == 1)[0][0]
    print("y = " + str(y_vec[j]) + " <=> pred = " + str(pred[j]))

print('Training Set Accuracy: %f' % (np.mean(pred == y_vec) * 100))
# Out:
# y = 0.0 <=> pred = 9
# y = 0.0 <=> pred = 0
# y = 0.0 <=> pred = 0
# y = 0.0 <=> pred = 0
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 9
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 8
# y = 0.0 <=> pred = 8
# y = 0.0 <=> pred = 8
# y = 0.0 <=> pred = 8
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 6
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 0
# y = 0.0 <=> pred = 0
# y = 0.0 <=> pred = 0
# y = 0.0 <=> pred = 0
# y = 0.0 <=> pred = 0
# y = 0.0 <=> pred = 0
# y = 0.0 <=> pred = 0
# y = 0.0 <=> pred = 0
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 6
# y = 0.0 <=> pred = 6
# y = 0.0 <=> pred = 6
# y = 0.0 <=> pred = 0
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 0
# y = 0.0 <=> pred = 0
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 0
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 6
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 0
# y = 0.0 <=> pred = 0
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 0
# y = 0.0 <=> pred = 0
# y = 0.0 <=> pred = 0
# y = 0.0 <=> pred = 0
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 9
# y = 0.0 <=> pred = 1
# y = 0.0 <=> pred = 9
# y = 0.0 <=> pred = 9
# y = 0.0 <=> pred = 6
# y = 0.0 <=> pred = 6
# y = 0.0 <=> pred = 0
# y = 0.0 <=> pred = 0
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 6
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 8
# y = 0.0 <=> pred = 8
# y = 0.0 <=> pred = 8
# y = 0.0 <=> pred = 8
# y = 0.0 <=> pred = 1
# y = 0.0 <=> pred = 1
# y = 0.0 <=> pred = 6
# y = 0.0 <=> pred = 1
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 0
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 6
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 3
# y = 0.0 <=> pred = 3
# y = 0.0 <=> pred = 3
# y = 0.0 <=> pred = 3
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 6
# y = 0.0 <=> pred = 6
# y = 0.0 <=> pred = 6
# y = 0.0 <=> pred = 6
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 9
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 9
# y = 0.0 <=> pred = 9
# y = 0.0 <=> pred = 9
# y = 0.0 <=> pred = 9
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 1
# y = 0.0 <=> pred = 1
# y = 0.0 <=> pred = 1
# y = 0.0 <=> pred = 1
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 1
# y = 0.0 <=> pred = 1
# y = 0.0 <=> pred = 1
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 9
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 0
# y = 0.0 <=> pred = 0
# y = 0.0 <=> pred = 6
# y = 0.0 <=> pred = 6
# y = 0.0 <=> pred = 0
# y = 0.0 <=> pred = 0
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 0
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 3
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 0
# y = 0.0 <=> pred = 0
# y = 0.0 <=> pred = 0
# y = 0.0 <=> pred = 0
# y = 0.0 <=> pred = 1
# y = 0.0 <=> pred = 1
# y = 0.0 <=> pred = 1
# y = 0.0 <=> pred = 1
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 9
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 0
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 0
# y = 0.0 <=> pred = 0
# y = 0.0 <=> pred = 0
# y = 0.0 <=> pred = 0
# y = 0.0 <=> pred = 1
# y = 0.0 <=> pred = 1
# y = 0.0 <=> pred = 1
# y = 0.0 <=> pred = 1
# y = 0.0 <=> pred = 3
# y = 0.0 <=> pred = 3
# y = 0.0 <=> pred = 3
# y = 0.0 <=> pred = 3
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 1
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 3
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 1
# y = 0.0 <=> pred = 1
# y = 0.0 <=> pred = 1
# y = 0.0 <=> pred = 9
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 9
# y = 0.0 <=> pred = 9
# y = 0.0 <=> pred = 9
# y = 0.0 <=> pred = 9
# y = 0.0 <=> pred = 8
# y = 0.0 <=> pred = 8
# y = 0.0 <=> pred = 8
# y = 0.0 <=> pred = 8
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 3
# y = 0.0 <=> pred = 3
# y = 0.0 <=> pred = 3
# y = 0.0 <=> pred = 3
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 9
# y = 0.0 <=> pred = 9
# y = 0.0 <=> pred = 9
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 9
# y = 0.0 <=> pred = 9
# y = 0.0 <=> pred = 9
# y = 0.0 <=> pred = 9
# y = 0.0 <=> pred = 9
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 3
# y = 0.0 <=> pred = 3
# y = 0.0 <=> pred = 3
# y = 0.0 <=> pred = 3
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 6
# y = 0.0 <=> pred = 1
# y = 0.0 <=> pred = 1
# y = 0.0 <=> pred = 1
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 6
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 6
# y = 0.0 <=> pred = 1
# y = 0.0 <=> pred = 1
# y = 0.0 <=> pred = 1
# y = 0.0 <=> pred = 1
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 1
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 1
# y = 0.0 <=> pred = 1
# y = 0.0 <=> pred = 1
# y = 0.0 <=> pred = 1
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 6
# y = 0.0 <=> pred = 1
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 1
# y = 0.0 <=> pred = 1
# y = 0.0 <=> pred = 1
# y = 0.0 <=> pred = 3
# y = 0.0 <=> pred = 3
# y = 0.0 <=> pred = 3
# y = 0.0 <=> pred = 3
# y = 0.0 <=> pred = 9
# y = 0.0 <=> pred = 1
# y = 0.0 <=> pred = 1
# y = 0.0 <=> pred = 1
# y = 0.0 <=> pred = 6
# y = 0.0 <=> pred = 6
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 6
# y = 0.0 <=> pred = 6
# y = 0.0 <=> pred = 6
# y = 0.0 <=> pred = 6
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 1
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 3
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 0
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 6
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 6
# y = 0.0 <=> pred = 6
# y = 0.0 <=> pred = 6
# y = 0.0 <=> pred = 6
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 6
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 6
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 3
# y = 0.0 <=> pred = 3
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 1
# y = 0.0 <=> pred = 1
# y = 0.0 <=> pred = 1
# y = 0.0 <=> pred = 1
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 6
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 6
# y = 0.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 8
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 8
# y = 1.0 <=> pred = 8
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 0
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 0
# y = 1.0 <=> pred = 0
# y = 1.0 <=> pred = 0
# y = 1.0 <=> pred = 0
# y = 1.0 <=> pred = 0
# y = 1.0 <=> pred = 0
# y = 1.0 <=> pred = 0
# y = 1.0 <=> pred = 0
# y = 1.0 <=> pred = 0
# y = 1.0 <=> pred = 0
# y = 1.0 <=> pred = 0
# y = 1.0 <=> pred = 0
# y = 1.0 <=> pred = 0
# y = 1.0 <=> pred = 0
# y = 1.0 <=> pred = 0
# y = 1.0 <=> pred = 0
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 0
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 0
# y = 1.0 <=> pred = 0
# y = 1.0 <=> pred = 0
# y = 1.0 <=> pred = 0
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 1
# y = 1.0 <=> pred = 1
# y = 1.0 <=> pred = 1
# y = 1.0 <=> pred = 0
# y = 1.0 <=> pred = 0
# y = 1.0 <=> pred = 0
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 0
# y = 1.0 <=> pred = 0
# y = 1.0 <=> pred = 0
# y = 1.0 <=> pred = 0
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 8
# y = 1.0 <=> pred = 8
# y = 1.0 <=> pred = 8
# y = 1.0 <=> pred = 8
# y = 1.0 <=> pred = 1
# y = 1.0 <=> pred = 1
# y = 1.0 <=> pred = 1
# y = 1.0 <=> pred = 9
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 0
# y = 1.0 <=> pred = 0
# y = 1.0 <=> pred = 0
# y = 1.0 <=> pred = 0
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 3
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 3
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 1
# y = 1.0 <=> pred = 1
# y = 1.0 <=> pred = 1
# y = 1.0 <=> pred = 1
# y = 1.0 <=> pred = 4
# y = 1.0 <=> pred = 1
# y = 1.0 <=> pred = 4
# y = 1.0 <=> pred = 4
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 0
# y = 1.0 <=> pred = 9
# y = 1.0 <=> pred = 1
# y = 1.0 <=> pred = 0
# y = 1.0 <=> pred = 0
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 1
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 0
# y = 1.0 <=> pred = 0
# y = 1.0 <=> pred = 0
# y = 1.0 <=> pred = 0
# y = 1.0 <=> pred = 6
# y = 1.0 <=> pred = 3
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 0
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 0
# y = 1.0 <=> pred = 0
# y = 1.0 <=> pred = 0
# y = 1.0 <=> pred = 0
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 0
# y = 1.0 <=> pred = 0
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 0
# y = 1.0 <=> pred = 0
# y = 1.0 <=> pred = 0
# y = 1.0 <=> pred = 0
# y = 1.0 <=> pred = 0
# y = 1.0 <=> pred = 0
# y = 1.0 <=> pred = 0
# y = 1.0 <=> pred = 0
# y = 1.0 <=> pred = 0
# y = 1.0 <=> pred = 0
# y = 1.0 <=> pred = 0
# y = 1.0 <=> pred = 0
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 1
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 3
# y = 1.0 <=> pred = 1
# y = 1.0 <=> pred = 3
# y = 1.0 <=> pred = 3
# y = 1.0 <=> pred = 3
# y = 1.0 <=> pred = 3
# y = 1.0 <=> pred = 3
# y = 1.0 <=> pred = 3
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 3
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 9
# y = 1.0 <=> pred = 9
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 9
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 9
# y = 1.0 <=> pred = 9
# y = 1.0 <=> pred = 9
# y = 1.0 <=> pred = 9
# y = 1.0 <=> pred = 3
# y = 1.0 <=> pred = 3
# y = 1.0 <=> pred = 3
# y = 1.0 <=> pred = 3
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 9
# y = 1.0 <=> pred = 9
# y = 1.0 <=> pred = 3
# y = 1.0 <=> pred = 3
# y = 1.0 <=> pred = 3
# y = 1.0 <=> pred = 3
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 9
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 6
# y = 1.0 <=> pred = 6
# y = 1.0 <=> pred = 6
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 6
# y = 1.0 <=> pred = 6
# y = 1.0 <=> pred = 6
# y = 1.0 <=> pred = 6
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 9
# y = 1.0 <=> pred = 0
# y = 1.0 <=> pred = 9
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 1
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 6
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 3
# y = 1.0 <=> pred = 3
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 1
# y = 1.0 <=> pred = 1
# y = 1.0 <=> pred = 1
# y = 1.0 <=> pred = 1
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 1
# y = 1.0 <=> pred = 1
# y = 1.0 <=> pred = 1
# y = 1.0 <=> pred = 1
# y = 1.0 <=> pred = 1
# y = 1.0 <=> pred = 1
# y = 1.0 <=> pred = 1
# y = 1.0 <=> pred = 1
# y = 1.0 <=> pred = 1
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 1
# y = 1.0 <=> pred = 1
# y = 1.0 <=> pred = 1
# y = 1.0 <=> pred = 9
# y = 1.0 <=> pred = 1
# y = 1.0 <=> pred = 9
# y = 1.0 <=> pred = 1
# y = 1.0 <=> pred = 3
# y = 1.0 <=> pred = 6
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 3
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 1
# y = 1.0 <=> pred = 6
# y = 1.0 <=> pred = 6
# y = 1.0 <=> pred = 1
# y = 1.0 <=> pred = 1
# y = 1.0 <=> pred = 1
# y = 1.0 <=> pred = 1
# y = 1.0 <=> pred = 0
# y = 1.0 <=> pred = 0
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 6
# y = 1.0 <=> pred = 6
# y = 1.0 <=> pred = 6
# y = 1.0 <=> pred = 6
# y = 1.0 <=> pred = 6
# y = 1.0 <=> pred = 6
# y = 1.0 <=> pred = 6
# y = 1.0 <=> pred = 6
# y = 1.0 <=> pred = 6
# y = 1.0 <=> pred = 6
# y = 1.0 <=> pred = 6
# y = 1.0 <=> pred = 6
# y = 1.0 <=> pred = 6
# y = 1.0 <=> pred = 6
# y = 1.0 <=> pred = 6
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 6
# y = 1.0 <=> pred = 6
# y = 1.0 <=> pred = 6
# y = 1.0 <=> pred = 6
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 9
# y = 1.0 <=> pred = 9
# y = 1.0 <=> pred = 9
# y = 1.0 <=> pred = 9
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 9
# y = 1.0 <=> pred = 9
# y = 1.0 <=> pred = 1
# y = 1.0 <=> pred = 1
# y = 1.0 <=> pred = 1
# y = 1.0 <=> pred = 1
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 1
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 1
# y = 1.0 <=> pred = 1
# y = 1.0 <=> pred = 1
# y = 1.0 <=> pred = 1
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 6
# y = 1.0 <=> pred = 6
# y = 1.0 <=> pred = 6
# y = 1.0 <=> pred = 6
# y = 2.0 <=> pred = 3
# y = 2.0 <=> pred = 3
# y = 2.0 <=> pred = 9
# y = 2.0 <=> pred = 3
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 8
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 8
# y = 2.0 <=> pred = 8
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 8
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 6
# y = 2.0 <=> pred = 6
# y = 2.0 <=> pred = 6
# y = 2.0 <=> pred = 6
# y = 2.0 <=> pred = 8
# y = 2.0 <=> pred = 6
# y = 2.0 <=> pred = 6
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 6
# y = 2.0 <=> pred = 6
# y = 2.0 <=> pred = 6
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 3
# y = 2.0 <=> pred = 3
# y = 2.0 <=> pred = 3
# y = 2.0 <=> pred = 3
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 4
# y = 2.0 <=> pred = 4
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 6
# y = 2.0 <=> pred = 6
# y = 2.0 <=> pred = 6
# y = 2.0 <=> pred = 6
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 8
# y = 2.0 <=> pred = 8
# y = 2.0 <=> pred = 8
# y = 2.0 <=> pred = 8
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 6
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 3
# y = 2.0 <=> pred = 3
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 3
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 3
# y = 2.0 <=> pred = 9
# y = 2.0 <=> pred = 9
# y = 2.0 <=> pred = 9
# y = 2.0 <=> pred = 9
# y = 2.0 <=> pred = 6
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 6
# y = 2.0 <=> pred = 6
# y = 2.0 <=> pred = 6
# y = 2.0 <=> pred = 6
# y = 2.0 <=> pred = 6
# y = 2.0 <=> pred = 6
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 9
# y = 2.0 <=> pred = 9
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 9
# y = 2.0 <=> pred = 9
# y = 2.0 <=> pred = 9
# y = 2.0 <=> pred = 9
# y = 2.0 <=> pred = 3
# y = 2.0 <=> pred = 3
# y = 2.0 <=> pred = 3
# y = 2.0 <=> pred = 3
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 9
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 9
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 9
# y = 2.0 <=> pred = 9
# y = 2.0 <=> pred = 3
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 3
# y = 2.0 <=> pred = 3
# y = 2.0 <=> pred = 3
# y = 2.0 <=> pred = 3
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 3
# y = 2.0 <=> pred = 3
# y = 2.0 <=> pred = 3
# y = 2.0 <=> pred = 3
# y = 2.0 <=> pred = 6
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 3
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 6
# y = 2.0 <=> pred = 6
# y = 2.0 <=> pred = 6
# y = 2.0 <=> pred = 6
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 6
# y = 2.0 <=> pred = 6
# y = 2.0 <=> pred = 6
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 6
# y = 2.0 <=> pred = 6
# y = 2.0 <=> pred = 6
# y = 2.0 <=> pred = 6
# y = 2.0 <=> pred = 6
# y = 2.0 <=> pred = 6
# y = 2.0 <=> pred = 6
# y = 2.0 <=> pred = 6
# y = 2.0 <=> pred = 6
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 6
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 6
# y = 2.0 <=> pred = 6
# y = 2.0 <=> pred = 6
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 6
# y = 2.0 <=> pred = 6
# y = 2.0 <=> pred = 6
# y = 2.0 <=> pred = 6
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 9
# y = 2.0 <=> pred = 9
# y = 2.0 <=> pred = 9
# y = 2.0 <=> pred = 9
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 3
# y = 2.0 <=> pred = 3
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 3
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 3
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 6
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 9
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 6
# y = 2.0 <=> pred = 6
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 8
# y = 3.0 <=> pred = 8
# y = 3.0 <=> pred = 8
# y = 3.0 <=> pred = 8
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 0
# y = 3.0 <=> pred = 0
# y = 3.0 <=> pred = 0
# y = 3.0 <=> pred = 0
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 0
# y = 3.0 <=> pred = 6
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 6
# y = 3.0 <=> pred = 0
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 1
# y = 3.0 <=> pred = 1
# y = 3.0 <=> pred = 1
# y = 3.0 <=> pred = 1
# y = 3.0 <=> pred = 0
# y = 3.0 <=> pred = 0
# y = 3.0 <=> pred = 0
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 0
# y = 3.0 <=> pred = 0
# y = 3.0 <=> pred = 0
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 3
# y = 3.0 <=> pred = 3
# y = 3.0 <=> pred = 3
# y = 3.0 <=> pred = 3
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 0
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 1
# y = 3.0 <=> pred = 6
# y = 3.0 <=> pred = 6
# y = 3.0 <=> pred = 6
# y = 3.0 <=> pred = 6
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 1
# y = 3.0 <=> pred = 6
# y = 3.0 <=> pred = 1
# y = 3.0 <=> pred = 1
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 6
# y = 3.0 <=> pred = 6
# y = 3.0 <=> pred = 6
# y = 3.0 <=> pred = 6
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 0
# y = 3.0 <=> pred = 0
# y = 3.0 <=> pred = 0
# y = 3.0 <=> pred = 0
# y = 3.0 <=> pred = 9
# y = 3.0 <=> pred = 9
# y = 3.0 <=> pred = 9
# y = 3.0 <=> pred = 1
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 0
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 1
# y = 3.0 <=> pred = 1
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 9
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 9
# y = 3.0 <=> pred = 9
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 0
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 0
# y = 3.0 <=> pred = 0
# y = 3.0 <=> pred = 0
# y = 3.0 <=> pred = 0
# y = 3.0 <=> pred = 0
# y = 3.0 <=> pred = 0
# y = 3.0 <=> pred = 0
# y = 3.0 <=> pred = 0
# y = 3.0 <=> pred = 1
# y = 3.0 <=> pred = 1
# y = 3.0 <=> pred = 1
# y = 3.0 <=> pred = 1
# y = 3.0 <=> pred = 3
# y = 3.0 <=> pred = 3
# y = 3.0 <=> pred = 3
# y = 3.0 <=> pred = 3
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 3
# y = 3.0 <=> pred = 3
# y = 3.0 <=> pred = 3
# y = 3.0 <=> pred = 3
# y = 3.0 <=> pred = 3
# y = 3.0 <=> pred = 3
# y = 3.0 <=> pred = 3
# y = 3.0 <=> pred = 3
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 1
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 3
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 3
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 1
# y = 3.0 <=> pred = 1
# y = 3.0 <=> pred = 1
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 1
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 1
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 3
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 3
# y = 3.0 <=> pred = 9
# y = 3.0 <=> pred = 9
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 9
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 9
# y = 3.0 <=> pred = 9
# y = 3.0 <=> pred = 1
# y = 3.0 <=> pred = 1
# y = 3.0 <=> pred = 1
# y = 3.0 <=> pred = 1
# y = 3.0 <=> pred = 1
# y = 3.0 <=> pred = 3
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 1
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 3
# y = 3.0 <=> pred = 3
# y = 3.0 <=> pred = 3
# y = 3.0 <=> pred = 3
# y = 3.0 <=> pred = 3
# y = 3.0 <=> pred = 3
# y = 3.0 <=> pred = 3
# y = 3.0 <=> pred = 3
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 1
# y = 3.0 <=> pred = 9
# y = 3.0 <=> pred = 9
# y = 3.0 <=> pred = 9
# y = 3.0 <=> pred = 9
# y = 3.0 <=> pred = 1
# y = 3.0 <=> pred = 1
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 1
# y = 3.0 <=> pred = 1
# y = 3.0 <=> pred = 1
# y = 3.0 <=> pred = 1
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 1
# y = 3.0 <=> pred = 1
# y = 3.0 <=> pred = 9
# y = 3.0 <=> pred = 9
# y = 3.0 <=> pred = 1
# y = 3.0 <=> pred = 1
# y = 3.0 <=> pred = 1
# y = 3.0 <=> pred = 1
# y = 3.0 <=> pred = 1
# y = 3.0 <=> pred = 1
# y = 3.0 <=> pred = 1
# y = 3.0 <=> pred = 1
# y = 3.0 <=> pred = 1
# y = 3.0 <=> pred = 1
# y = 3.0 <=> pred = 6
# y = 3.0 <=> pred = 6
# y = 3.0 <=> pred = 6
# y = 3.0 <=> pred = 6
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 6
# y = 3.0 <=> pred = 6
# y = 3.0 <=> pred = 1
# y = 3.0 <=> pred = 1
# y = 3.0 <=> pred = 1
# y = 3.0 <=> pred = 1
# y = 3.0 <=> pred = 1
# y = 3.0 <=> pred = 1
# y = 3.0 <=> pred = 1
# y = 3.0 <=> pred = 1
# y = 3.0 <=> pred = 1
# y = 3.0 <=> pred = 1
# y = 3.0 <=> pred = 6
# y = 3.0 <=> pred = 6
# y = 3.0 <=> pred = 1
# y = 3.0 <=> pred = 1
# y = 3.0 <=> pred = 1
# y = 3.0 <=> pred = 1
# y = 3.0 <=> pred = 1
# y = 3.0 <=> pred = 6
# y = 3.0 <=> pred = 6
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 1
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 1
# y = 3.0 <=> pred = 1
# y = 3.0 <=> pred = 3
# y = 3.0 <=> pred = 3
# y = 3.0 <=> pred = 3
# y = 3.0 <=> pred = 1
# y = 3.0 <=> pred = 6
# y = 3.0 <=> pred = 6
# y = 3.0 <=> pred = 6
# y = 3.0 <=> pred = 6
# y = 3.0 <=> pred = 6
# y = 3.0 <=> pred = 6
# y = 3.0 <=> pred = 6
# y = 3.0 <=> pred = 6
# y = 3.0 <=> pred = 6
# y = 3.0 <=> pred = 6
# y = 3.0 <=> pred = 6
# y = 3.0 <=> pred = 6
# y = 3.0 <=> pred = 6
# y = 3.0 <=> pred = 6
# y = 3.0 <=> pred = 6
# y = 3.0 <=> pred = 6
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 6
# y = 3.0 <=> pred = 6
# y = 3.0 <=> pred = 6
# y = 3.0 <=> pred = 6
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 9
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 1
# y = 3.0 <=> pred = 1
# y = 3.0 <=> pred = 1
# y = 3.0 <=> pred = 1
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 6
# y = 3.0 <=> pred = 6
# y = 3.0 <=> pred = 6
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 6
# y = 3.0 <=> pred = 6
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 6
# y = 3.0 <=> pred = 6
# y = 3.0 <=> pred = 6
# y = 3.0 <=> pred = 6
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 9
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 1
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 6
# y = 3.0 <=> pred = 6
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 6
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 1
# y = 4.0 <=> pred = 1
# y = 4.0 <=> pred = 1
# y = 4.0 <=> pred = 1
# y = 4.0 <=> pred = 1
# y = 4.0 <=> pred = 1
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 1
# y = 4.0 <=> pred = 1
# y = 4.0 <=> pred = 1
# y = 4.0 <=> pred = 6
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 1
# y = 4.0 <=> pred = 1
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 0
# y = 4.0 <=> pred = 0
# y = 4.0 <=> pred = 0
# y = 4.0 <=> pred = 0
# y = 4.0 <=> pred = 6
# y = 4.0 <=> pred = 6
# y = 4.0 <=> pred = 6
# y = 4.0 <=> pred = 6
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 0
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 1
# y = 4.0 <=> pred = 0
# y = 4.0 <=> pred = 1
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 1
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 6
# y = 4.0 <=> pred = 6
# y = 4.0 <=> pred = 6
# y = 4.0 <=> pred = 6
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 0
# y = 4.0 <=> pred = 0
# y = 4.0 <=> pred = 0
# y = 4.0 <=> pred = 0
# y = 4.0 <=> pred = 0
# y = 4.0 <=> pred = 0
# y = 4.0 <=> pred = 0
# y = 4.0 <=> pred = 0
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 3
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 1
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 1
# y = 4.0 <=> pred = 1
# y = 4.0 <=> pred = 1
# y = 4.0 <=> pred = 1
# y = 4.0 <=> pred = 0
# y = 4.0 <=> pred = 0
# y = 4.0 <=> pred = 0
# y = 4.0 <=> pred = 0
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 9
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 0
# y = 4.0 <=> pred = 0
# y = 4.0 <=> pred = 0
# y = 4.0 <=> pred = 0
# y = 4.0 <=> pred = 0
# y = 4.0 <=> pred = 0
# y = 4.0 <=> pred = 0
# y = 4.0 <=> pred = 0
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# ...
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 6
# y = 11.0 <=> pred = 9
# y = 11.0 <=> pred = 9
# y = 11.0 <=> pred = 9
# y = 11.0 <=> pred = 9
# y = 11.0 <=> pred = 9
# y = 11.0 <=> pred = 9
# y = 11.0 <=> pred = 9
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 6
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 9
# y = 11.0 <=> pred = 9
# y = 11.0 <=> pred = 9
# y = 11.0 <=> pred = 9
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 6
# y = 11.0 <=> pred = 6
# y = 11.0 <=> pred = 6
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 9
# y = 11.0 <=> pred = 9
# y = 11.0 <=> pred = 9
# y = 11.0 <=> pred = 9
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 9
# y = 11.0 <=> pred = 9
# y = 11.0 <=> pred = 9
# y = 11.0 <=> pred = 9
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 1
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 6
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 6
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 9
# y = 11.0 <=> pred = 9
# y = 11.0 <=> pred = 9
# y = 11.0 <=> pred = 9
# y = 11.0 <=> pred = 6
# y = 11.0 <=> pred = 6
# y = 11.0 <=> pred = 6
# y = 11.0 <=> pred = 6
# y = 11.0 <=> pred = 6
# y = 11.0 <=> pred = 6
# y = 11.0 <=> pred = 6
# y = 11.0 <=> pred = 6
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 6
# y = 11.0 <=> pred = 6
# y = 11.0 <=> pred = 6
# y = 11.0 <=> pred = 6
# y = 11.0 <=> pred = 6
# y = 11.0 <=> pred = 6
# y = 11.0 <=> pred = 6
# y = 11.0 <=> pred = 6
# y = 11.0 <=> pred = 6
# y = 11.0 <=> pred = 6
# y = 11.0 <=> pred = 6
# y = 11.0 <=> pred = 6
# y = 11.0 <=> pred = 6
# y = 11.0 <=> pred = 6
# y = 11.0 <=> pred = 6
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 6
# y = 11.0 <=> pred = 6
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 6
# y = 11.0 <=> pred = 6
# y = 11.0 <=> pred = 6
# y = 11.0 <=> pred = 6
# y = 11.0 <=> pred = 1
# y = 11.0 <=> pred = 1
# y = 11.0 <=> pred = 1
# y = 11.0 <=> pred = 1
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 6
# y = 11.0 <=> pred = 6
# y = 11.0 <=> pred = 6
# y = 11.0 <=> pred = 6
# y = 11.0 <=> pred = 6
# y = 11.0 <=> pred = 6
# y = 11.0 <=> pred = 6
# y = 11.0 <=> pred = 6
# y = 11.0 <=> pred = 6
# y = 11.0 <=> pred = 6
# y = 11.0 <=> pred = 6
# y = 11.0 <=> pred = 6
# y = 11.0 <=> pred = 6
# y = 11.0 <=> pred = 6
# y = 11.0 <=> pred = 6
# y = 11.0 <=> pred = 6
# y = 11.0 <=> pred = 6
# y = 11.0 <=> pred = 6
# y = 11.0 <=> pred = 6
# y = 11.0 <=> pred = 6
# y = 11.0 <=> pred = 6
# y = 11.0 <=> pred = 6
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 6
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 6
# y = 11.0 <=> pred = 6
# y = 11.0 <=> pred = 6
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 6
# y = 11.0 <=> pred = 6
# y = 11.0 <=> pred = 6
# y = 11.0 <=> pred = 6
# y = 11.0 <=> pred = 6
# y = 11.0 <=> pred = 6
# y = 11.0 <=> pred = 6
# y = 11.0 <=> pred = 6
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 6
# y = 11.0 <=> pred = 6
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 12.0 <=> pred = 1
# y = 12.0 <=> pred = 1
# y = 12.0 <=> pred = 1
# y = 12.0 <=> pred = 1
# y = 12.0 <=> pred = 1
# y = 12.0 <=> pred = 1
# y = 12.0 <=> pred = 1
# y = 12.0 <=> pred = 1
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 9
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 1
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 1
# y = 12.0 <=> pred = 1
# y = 12.0 <=> pred = 3
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 6
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 9
# y = 12.0 <=> pred = 1
# y = 12.0 <=> pred = 1
# y = 12.0 <=> pred = 1
# y = 12.0 <=> pred = 1
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 1
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 1
# y = 12.0 <=> pred = 1
# y = 12.0 <=> pred = 1
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 1
# y = 12.0 <=> pred = 1
# y = 12.0 <=> pred = 1
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 6
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 0
# y = 12.0 <=> pred = 3
# y = 12.0 <=> pred = 3
# y = 12.0 <=> pred = 3
# y = 12.0 <=> pred = 3
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 9
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 3
# y = 12.0 <=> pred = 3
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 3
# y = 12.0 <=> pred = 1
# y = 12.0 <=> pred = 1
# y = 12.0 <=> pred = 1
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 1
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 1
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 9
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 0
# y = 12.0 <=> pred = 0
# y = 12.0 <=> pred = 0
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 9
# y = 12.0 <=> pred = 9
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 1
# y = 12.0 <=> pred = 1
# y = 12.0 <=> pred = 1
# y = 12.0 <=> pred = 1
# y = 12.0 <=> pred = 9
# y = 12.0 <=> pred = 9
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 9
# y = 12.0 <=> pred = 9
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 9
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 9
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 1
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 8
# y = 12.0 <=> pred = 6
# y = 12.0 <=> pred = 6
# y = 12.0 <=> pred = 8
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 9
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 9
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 1
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 1
# y = 12.0 <=> pred = 1
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 6
# y = 12.0 <=> pred = 6
# y = 12.0 <=> pred = 6
# y = 12.0 <=> pred = 6
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 9
# y = 12.0 <=> pred = 1
# y = 12.0 <=> pred = 1
# y = 12.0 <=> pred = 1
# y = 12.0 <=> pred = 1
# y = 12.0 <=> pred = 1
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 1
# y = 12.0 <=> pred = 1
# y = 12.0 <=> pred = 1
# y = 12.0 <=> pred = 1
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 0
# y = 12.0 <=> pred = 0
# y = 12.0 <=> pred = 1
# y = 12.0 <=> pred = 1
# y = 12.0 <=> pred = 9
# y = 12.0 <=> pred = 0
# y = 12.0 <=> pred = 0
# y = 12.0 <=> pred = 0
# y = 12.0 <=> pred = 6
# y = 12.0 <=> pred = 6
# y = 12.0 <=> pred = 0
# y = 12.0 <=> pred = 0
# y = 12.0 <=> pred = 9
# y = 12.0 <=> pred = 9
# y = 12.0 <=> pred = 9
# y = 12.0 <=> pred = 9
# y = 12.0 <=> pred = 6
# y = 12.0 <=> pred = 9
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 1
# y = 12.0 <=> pred = 1
# y = 12.0 <=> pred = 1
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 1
# y = 12.0 <=> pred = 1
# y = 12.0 <=> pred = 1
# y = 12.0 <=> pred = 1
# y = 12.0 <=> pred = 6
# y = 12.0 <=> pred = 6
# y = 12.0 <=> pred = 6
# y = 12.0 <=> pred = 6
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 6
# y = 12.0 <=> pred = 6
# y = 12.0 <=> pred = 6
# y = 12.0 <=> pred = 6
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 6
# y = 12.0 <=> pred = 6
# y = 12.0 <=> pred = 1
# y = 12.0 <=> pred = 1
# y = 12.0 <=> pred = 1
# y = 12.0 <=> pred = 1
# y = 12.0 <=> pred = 1
# y = 12.0 <=> pred = 6
# y = 12.0 <=> pred = 1
# y = 12.0 <=> pred = 1
# y = 12.0 <=> pred = 6
# y = 12.0 <=> pred = 6
# y = 12.0 <=> pred = 6
# y = 12.0 <=> pred = 1
# y = 12.0 <=> pred = 1
# y = 12.0 <=> pred = 1
# y = 12.0 <=> pred = 6
# y = 12.0 <=> pred = 6
# y = 12.0 <=> pred = 6
# y = 12.0 <=> pred = 6
# y = 12.0 <=> pred = 1
# y = 12.0 <=> pred = 1
# y = 12.0 <=> pred = 1
# y = 12.0 <=> pred = 1
# y = 12.0 <=> pred = 1
# y = 12.0 <=> pred = 1
# y = 12.0 <=> pred = 1
# y = 12.0 <=> pred = 1
# y = 12.0 <=> pred = 6
# y = 12.0 <=> pred = 6
# y = 12.0 <=> pred = 6
# y = 12.0 <=> pred = 6
# y = 12.0 <=> pred = 6
# y = 12.0 <=> pred = 6
# y = 12.0 <=> pred = 6
# y = 12.0 <=> pred = 6
# y = 12.0 <=> pred = 1
# y = 12.0 <=> pred = 1
# y = 12.0 <=> pred = 8
# y = 12.0 <=> pred = 1
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 1
# y = 12.0 <=> pred = 6
# y = 12.0 <=> pred = 6
# y = 12.0 <=> pred = 12
# Training Set Accuracy: 8.769231

# %% [markdown]
# ## try the trained neural network on the test data
# The accuracy of the neural network is tested on the test data.

# %%
pred_test = utils.predict(Theta1, Theta2, X_test)
y_test_vec = np.zeros(y_test.shape[0])

for j in range(y_test_vec.shape[0]):
    y_test_vec[j] = np.where(y_test[j,:] == 1)[0][0]
    print("y = " + str(y_test_vec[j]) + " <=> pred = " + str(pred_test[j]))

print('Test Set Accuracy: %f' % (np.mean(pred_test == y_test_vec) * 100))
# Out:
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 0
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 0
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 1
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 1
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 0
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 8
# y = 0.0 <=> pred = 8
# y = 0.0 <=> pred = 1
# y = 0.0 <=> pred = 3
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 3
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 0
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 0
# y = 0.0 <=> pred = 6
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 6
# y = 0.0 <=> pred = 6
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 0
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 0
# y = 0.0 <=> pred = 9
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 0
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 1
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 1
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 1
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 9
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 3
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 1
# y = 0.0 <=> pred = 9
# y = 0.0 <=> pred = 3
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 6
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 6
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 1
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 6
# y = 0.0 <=> pred = 1
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 6
# y = 0.0 <=> pred = 6
# y = 0.0 <=> pred = 6
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 1
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 6
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 9
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 6
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 6
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 6
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 6
# y = 0.0 <=> pred = 1
# y = 0.0 <=> pred = 1
# y = 0.0 <=> pred = 12
# y = 0.0 <=> pred = 6
# y = 0.0 <=> pred = 6
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 1
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 1
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 9
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 1
# y = 1.0 <=> pred = 0
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 1
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 1
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 3
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 6
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 0
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 0
# y = 1.0 <=> pred = 0
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 0
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 0
# y = 1.0 <=> pred = 0
# y = 1.0 <=> pred = 0
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 0
# y = 1.0 <=> pred = 0
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 0
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 0
# y = 1.0 <=> pred = 0
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 3
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 3
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 3
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 3
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 9
# y = 1.0 <=> pred = 9
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 3
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 6
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 1
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 1
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 1
# y = 1.0 <=> pred = 1
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 1
# y = 1.0 <=> pred = 6
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 1
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 6
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 6
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 6
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 6
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 12
# y = 1.0 <=> pred = 6
# y = 1.0 <=> pred = 6
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 9
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 8
# y = 2.0 <=> pred = 8
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 6
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 6
# y = 2.0 <=> pred = 6
# y = 2.0 <=> pred = 6
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 3
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 3
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 6
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 6
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 6
# y = 2.0 <=> pred = 8
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 0
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 3
# y = 2.0 <=> pred = 3
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 3
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 9
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 9
# y = 2.0 <=> pred = 6
# y = 2.0 <=> pred = 3
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 6
# y = 2.0 <=> pred = 3
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 3
# y = 2.0 <=> pred = 6
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 3
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 6
# y = 2.0 <=> pred = 6
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 6
# y = 2.0 <=> pred = 6
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 6
# y = 2.0 <=> pred = 6
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 9
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 3
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 6
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 1
# y = 2.0 <=> pred = 12
# y = 2.0 <=> pred = 3
# y = 2.0 <=> pred = 6
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 1
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 1
# y = 3.0 <=> pred = 8
# y = 3.0 <=> pred = 8
# y = 3.0 <=> pred = 8
# y = 3.0 <=> pred = 0
# y = 3.0 <=> pred = 0
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 0
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 0
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 9
# y = 3.0 <=> pred = 6
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 0
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 0
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 0
# y = 3.0 <=> pred = 0
# y = 3.0 <=> pred = 0
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 0
# y = 3.0 <=> pred = 0
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 0
# y = 3.0 <=> pred = 0
# y = 3.0 <=> pred = 1
# y = 3.0 <=> pred = 3
# y = 3.0 <=> pred = 3
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 3
# y = 3.0 <=> pred = 3
# y = 3.0 <=> pred = 3
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 3
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 1
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 9
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 3
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 3
# y = 3.0 <=> pred = 9
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 1
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 3
# y = 3.0 <=> pred = 6
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 1
# y = 3.0 <=> pred = 1
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 6
# y = 3.0 <=> pred = 3
# y = 3.0 <=> pred = 1
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 6
# y = 3.0 <=> pred = 6
# y = 3.0 <=> pred = 6
# y = 3.0 <=> pred = 6
# y = 3.0 <=> pred = 9
# y = 3.0 <=> pred = 6
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 6
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 6
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 6
# y = 3.0 <=> pred = 6
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 6
# y = 3.0 <=> pred = 6
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 3
# y = 3.0 <=> pred = 6
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 9
# y = 3.0 <=> pred = 12
# y = 3.0 <=> pred = 9
# y = 3.0 <=> pred = 3
# y = 3.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 6
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 1
# y = 4.0 <=> pred = 1
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 1
# y = 4.0 <=> pred = 1
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 1
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 1
# y = 4.0 <=> pred = 1
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 0
# y = 4.0 <=> pred = 0
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 1
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 0
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 9
# y = 4.0 <=> pred = 0
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 9
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 1
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 1
# y = 4.0 <=> pred = 6
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 6
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 6
# y = 4.0 <=> pred = 6
# y = 4.0 <=> pred = 0
# y = 4.0 <=> pred = 6
# y = 4.0 <=> pred = 6
# y = 4.0 <=> pred = 1
# y = 4.0 <=> pred = 1
# y = 4.0 <=> pred = 9
# y = 4.0 <=> pred = 8
# y = 4.0 <=> pred = 9
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 1
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 9
# y = 4.0 <=> pred = 8
# y = 4.0 <=> pred = 6
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 6
# y = 4.0 <=> pred = 6
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 6
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 6
# y = 4.0 <=> pred = 8
# y = 4.0 <=> pred = 6
# y = 4.0 <=> pred = 6
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 1
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 0
# y = 4.0 <=> pred = 0
# y = 4.0 <=> pred = 9
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 1
# y = 4.0 <=> pred = 6
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 6
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 6
# y = 4.0 <=> pred = 12
# y = 4.0 <=> pred = 6
# y = 5.0 <=> pred = 12
# y = 5.0 <=> pred = 12
# y = 5.0 <=> pred = 12
# y = 5.0 <=> pred = 12
# y = 5.0 <=> pred = 6
# y = 5.0 <=> pred = 12
# y = 5.0 <=> pred = 12
# y = 5.0 <=> pred = 12
# y = 5.0 <=> pred = 12
# y = 5.0 <=> pred = 12
# y = 5.0 <=> pred = 9
# y = 5.0 <=> pred = 9
# y = 5.0 <=> pred = 12
# y = 5.0 <=> pred = 12
# y = 5.0 <=> pred = 12
# y = 5.0 <=> pred = 12
# y = 5.0 <=> pred = 12
# y = 5.0 <=> pred = 12
# y = 5.0 <=> pred = 12
# y = 5.0 <=> pred = 12
# y = 5.0 <=> pred = 9
# y = 5.0 <=> pred = 12
# y = 5.0 <=> pred = 1
# y = 5.0 <=> pred = 12
# y = 5.0 <=> pred = 12
# y = 5.0 <=> pred = 12
# y = 5.0 <=> pred = 12
# y = 5.0 <=> pred = 12
# y = 5.0 <=> pred = 12
# y = 5.0 <=> pred = 12
# y = 5.0 <=> pred = 12
# y = 5.0 <=> pred = 12
# y = 5.0 <=> pred = 12
# y = 5.0 <=> pred = 12
# y = 5.0 <=> pred = 12
# y = 5.0 <=> pred = 12
# y = 5.0 <=> pred = 12
# y = 5.0 <=> pred = 12
# y = 5.0 <=> pred = 12
# y = 5.0 <=> pred = 12
# y = 5.0 <=> pred = 12
# y = 5.0 <=> pred = 12
# y = 5.0 <=> pred = 12
# y = 5.0 <=> pred = 12
# y = 5.0 <=> pred = 12
# y = 5.0 <=> pred = 12
# y = 5.0 <=> pred = 12
# y = 5.0 <=> pred = 12
# y = 5.0 <=> pred = 12
# y = 5.0 <=> pred = 12
# y = 5.0 <=> pred = 12
# y = 5.0 <=> pred = 12
# y = 5.0 <=> pred = 12
# y = 5.0 <=> pred = 12
# y = 5.0 <=> pred = 12
# y = 5.0 <=> pred = 12
# y = 5.0 <=> pred = 12
# y = 5.0 <=> pred = 12
# y = 5.0 <=> pred = 12
# y = 5.0 <=> pred = 1
# y = 5.0 <=> pred = 12
# y = 5.0 <=> pred = 12
# y = 5.0 <=> pred = 12
# y = 5.0 <=> pred = 12
# y = 5.0 <=> pred = 1
# y = 5.0 <=> pred = 12
# y = 5.0 <=> pred = 12
# y = 5.0 <=> pred = 12
# y = 5.0 <=> pred = 12
# y = 5.0 <=> pred = 12
# y = 5.0 <=> pred = 12
# y = 5.0 <=> pred = 12
# y = 5.0 <=> pred = 12
# y = 5.0 <=> pred = 12
# y = 5.0 <=> pred = 12
# y = 5.0 <=> pred = 12
# y = 5.0 <=> pred = 12
# y = 5.0 <=> pred = 8
# y = 5.0 <=> pred = 6
# y = 5.0 <=> pred = 1
# y = 5.0 <=> pred = 12
# y = 5.0 <=> pred = 12
# y = 5.0 <=> pred = 1
# y = 5.0 <=> pred = 12
# y = 5.0 <=> pred = 1
# y = 5.0 <=> pred = 8
# y = 5.0 <=> pred = 9
# y = 5.0 <=> pred = 12
# y = 5.0 <=> pred = 12
# y = 5.0 <=> pred = 12
# y = 5.0 <=> pred = 9
# y = 5.0 <=> pred = 6
# y = 5.0 <=> pred = 12
# y = 5.0 <=> pred = 6
# y = 5.0 <=> pred = 12
# y = 5.0 <=> pred = 12
# y = 5.0 <=> pred = 12
# y = 5.0 <=> pred = 12
# y = 5.0 <=> pred = 6
# y = 5.0 <=> pred = 12
# y = 5.0 <=> pred = 12
# y = 5.0 <=> pred = 6
# y = 5.0 <=> pred = 6
# y = 5.0 <=> pred = 12
# y = 5.0 <=> pred = 12
# y = 5.0 <=> pred = 0
# y = 5.0 <=> pred = 6
# y = 5.0 <=> pred = 6
# y = 5.0 <=> pred = 12
# y = 5.0 <=> pred = 12
# y = 5.0 <=> pred = 8
# y = 5.0 <=> pred = 12
# y = 5.0 <=> pred = 6
# y = 5.0 <=> pred = 6
# y = 5.0 <=> pred = 6
# y = 5.0 <=> pred = 6
# y = 5.0 <=> pred = 12
# y = 5.0 <=> pred = 12
# y = 5.0 <=> pred = 12
# y = 5.0 <=> pred = 6
# y = 5.0 <=> pred = 6
# y = 5.0 <=> pred = 12
# y = 5.0 <=> pred = 9
# y = 5.0 <=> pred = 12
# y = 5.0 <=> pred = 6
# y = 6.0 <=> pred = 12
# y = 6.0 <=> pred = 1
# y = 6.0 <=> pred = 9
# y = 6.0 <=> pred = 1
# y = 6.0 <=> pred = 1
# y = 6.0 <=> pred = 12
# y = 6.0 <=> pred = 12
# y = 6.0 <=> pred = 1
# y = 6.0 <=> pred = 12
# y = 6.0 <=> pred = 1
# y = 6.0 <=> pred = 3
# y = 6.0 <=> pred = 1
# y = 6.0 <=> pred = 8
# y = 6.0 <=> pred = 1
# y = 6.0 <=> pred = 1
# y = 6.0 <=> pred = 1
# y = 6.0 <=> pred = 12
# y = 6.0 <=> pred = 9
# y = 6.0 <=> pred = 1
# y = 6.0 <=> pred = 12
# y = 6.0 <=> pred = 1
# y = 6.0 <=> pred = 9
# y = 6.0 <=> pred = 12
# y = 6.0 <=> pred = 1
# y = 6.0 <=> pred = 12
# y = 6.0 <=> pred = 0
# y = 6.0 <=> pred = 12
# y = 6.0 <=> pred = 12
# y = 6.0 <=> pred = 12
# y = 6.0 <=> pred = 12
# y = 6.0 <=> pred = 1
# y = 6.0 <=> pred = 12
# y = 6.0 <=> pred = 1
# y = 6.0 <=> pred = 12
# y = 6.0 <=> pred = 12
# y = 6.0 <=> pred = 9
# y = 6.0 <=> pred = 12
# y = 6.0 <=> pred = 12
# y = 6.0 <=> pred = 1
# y = 6.0 <=> pred = 1
# y = 6.0 <=> pred = 12
# y = 6.0 <=> pred = 12
# y = 6.0 <=> pred = 1
# y = 6.0 <=> pred = 12
# y = 6.0 <=> pred = 12
# y = 6.0 <=> pred = 12
# y = 6.0 <=> pred = 12
# y = 6.0 <=> pred = 12
# y = 6.0 <=> pred = 12
# y = 6.0 <=> pred = 1
# y = 6.0 <=> pred = 12
# y = 6.0 <=> pred = 0
# y = 6.0 <=> pred = 2
# y = 6.0 <=> pred = 0
# y = 6.0 <=> pred = 8
# y = 6.0 <=> pred = 12
# y = 6.0 <=> pred = 12
# y = 6.0 <=> pred = 3
# y = 6.0 <=> pred = 12
# y = 6.0 <=> pred = 12
# y = 6.0 <=> pred = 12
# y = 6.0 <=> pred = 12
# y = 6.0 <=> pred = 8
# y = 6.0 <=> pred = 12
# y = 6.0 <=> pred = 12
# y = 6.0 <=> pred = 12
# y = 6.0 <=> pred = 9
# y = 6.0 <=> pred = 12
# y = 6.0 <=> pred = 8
# y = 6.0 <=> pred = 9
# y = 6.0 <=> pred = 12
# y = 6.0 <=> pred = 9
# y = 6.0 <=> pred = 3
# y = 6.0 <=> pred = 1
# y = 6.0 <=> pred = 9
# y = 6.0 <=> pred = 6
# y = 6.0 <=> pred = 12
# y = 6.0 <=> pred = 8
# y = 6.0 <=> pred = 8
# y = 6.0 <=> pred = 12
# y = 6.0 <=> pred = 12
# y = 6.0 <=> pred = 12
# y = 6.0 <=> pred = 6
# y = 6.0 <=> pred = 12
# y = 6.0 <=> pred = 1
# y = 6.0 <=> pred = 8
# y = 6.0 <=> pred = 12
# y = 6.0 <=> pred = 12
# y = 6.0 <=> pred = 6
# y = 6.0 <=> pred = 12
# y = 6.0 <=> pred = 1
# y = 6.0 <=> pred = 12
# y = 6.0 <=> pred = 12
# y = 6.0 <=> pred = 12
# y = 6.0 <=> pred = 12
# y = 6.0 <=> pred = 1
# y = 6.0 <=> pred = 1
# y = 6.0 <=> pred = 9
# y = 6.0 <=> pred = 12
# y = 6.0 <=> pred = 12
# y = 6.0 <=> pred = 6
# y = 6.0 <=> pred = 6
# y = 6.0 <=> pred = 1
# y = 6.0 <=> pred = 6
# y = 6.0 <=> pred = 12
# y = 6.0 <=> pred = 6
# y = 6.0 <=> pred = 6
# y = 6.0 <=> pred = 3
# y = 6.0 <=> pred = 12
# y = 6.0 <=> pred = 12
# y = 6.0 <=> pred = 6
# y = 6.0 <=> pred = 12
# y = 6.0 <=> pred = 6
# y = 6.0 <=> pred = 12
# y = 6.0 <=> pred = 6
# y = 6.0 <=> pred = 12
# y = 6.0 <=> pred = 12
# y = 6.0 <=> pred = 12
# y = 6.0 <=> pred = 6
# y = 6.0 <=> pred = 6
# y = 6.0 <=> pred = 12
# y = 6.0 <=> pred = 0
# y = 6.0 <=> pred = 0
# y = 6.0 <=> pred = 6
# y = 6.0 <=> pred = 6
# y = 7.0 <=> pred = 12
# y = 7.0 <=> pred = 12
# y = 7.0 <=> pred = 3
# y = 7.0 <=> pred = 1
# y = 7.0 <=> pred = 12
# y = 7.0 <=> pred = 12
# y = 7.0 <=> pred = 12
# y = 7.0 <=> pred = 1
# y = 7.0 <=> pred = 12
# y = 7.0 <=> pred = 12
# y = 7.0 <=> pred = 12
# y = 7.0 <=> pred = 8
# y = 7.0 <=> pred = 1
# y = 7.0 <=> pred = 1
# y = 7.0 <=> pred = 1
# y = 7.0 <=> pred = 12
# y = 7.0 <=> pred = 12
# y = 7.0 <=> pred = 9
# y = 7.0 <=> pred = 12
# y = 7.0 <=> pred = 8
# y = 7.0 <=> pred = 12
# y = 7.0 <=> pred = 12
# y = 7.0 <=> pred = 12
# y = 7.0 <=> pred = 1
# y = 7.0 <=> pred = 12
# y = 7.0 <=> pred = 8
# y = 7.0 <=> pred = 1
# y = 7.0 <=> pred = 0
# y = 7.0 <=> pred = 12
# y = 7.0 <=> pred = 12
# y = 7.0 <=> pred = 8
# y = 7.0 <=> pred = 0
# y = 7.0 <=> pred = 12
# y = 7.0 <=> pred = 1
# y = 7.0 <=> pred = 1
# y = 7.0 <=> pred = 12
# y = 7.0 <=> pred = 1
# y = 7.0 <=> pred = 12
# y = 7.0 <=> pred = 12
# y = 7.0 <=> pred = 1
# y = 7.0 <=> pred = 12
# y = 7.0 <=> pred = 12
# y = 7.0 <=> pred = 6
# y = 7.0 <=> pred = 12
# y = 7.0 <=> pred = 1
# y = 7.0 <=> pred = 1
# y = 7.0 <=> pred = 12
# y = 7.0 <=> pred = 8
# y = 7.0 <=> pred = 12
# y = 7.0 <=> pred = 0
# y = 7.0 <=> pred = 12
# y = 7.0 <=> pred = 12
# y = 7.0 <=> pred = 12
# y = 7.0 <=> pred = 3
# y = 7.0 <=> pred = 1
# y = 7.0 <=> pred = 12
# y = 7.0 <=> pred = 3
# y = 7.0 <=> pred = 3
# y = 7.0 <=> pred = 12
# y = 7.0 <=> pred = 12
# y = 7.0 <=> pred = 1
# y = 7.0 <=> pred = 2
# y = 7.0 <=> pred = 12
# y = 7.0 <=> pred = 12
# y = 7.0 <=> pred = 12
# y = 7.0 <=> pred = 9
# y = 7.0 <=> pred = 3
# y = 7.0 <=> pred = 8
# y = 7.0 <=> pred = 3
# y = 7.0 <=> pred = 12
# y = 7.0 <=> pred = 1
# y = 7.0 <=> pred = 3
# y = 7.0 <=> pred = 3
# y = 7.0 <=> pred = 12
# y = 7.0 <=> pred = 9
# y = 7.0 <=> pred = 6
# y = 7.0 <=> pred = 12
# y = 7.0 <=> pred = 12
# y = 7.0 <=> pred = 12
# y = 7.0 <=> pred = 1
# y = 7.0 <=> pred = 12
# y = 7.0 <=> pred = 12
# y = 7.0 <=> pred = 12
# y = 7.0 <=> pred = 6
# y = 7.0 <=> pred = 12
# y = 7.0 <=> pred = 6
# y = 7.0 <=> pred = 1
# y = 7.0 <=> pred = 12
# y = 7.0 <=> pred = 1
# y = 7.0 <=> pred = 12
# y = 7.0 <=> pred = 9
# y = 7.0 <=> pred = 1
# y = 7.0 <=> pred = 12
# y = 7.0 <=> pred = 12
# y = 7.0 <=> pred = 6
# y = 7.0 <=> pred = 9
# y = 7.0 <=> pred = 1
# y = 7.0 <=> pred = 12
# y = 7.0 <=> pred = 12
# y = 7.0 <=> pred = 12
# y = 7.0 <=> pred = 6
# y = 7.0 <=> pred = 0
# y = 7.0 <=> pred = 1
# y = 7.0 <=> pred = 6
# y = 7.0 <=> pred = 6
# y = 7.0 <=> pred = 6
# y = 7.0 <=> pred = 6
# y = 7.0 <=> pred = 12
# y = 7.0 <=> pred = 12
# y = 7.0 <=> pred = 12
# y = 7.0 <=> pred = 12
# y = 7.0 <=> pred = 12
# y = 7.0 <=> pred = 12
# y = 7.0 <=> pred = 12
# y = 7.0 <=> pred = 12
# y = 7.0 <=> pred = 9
# y = 7.0 <=> pred = 9
# y = 7.0 <=> pred = 12
# y = 7.0 <=> pred = 6
# y = 7.0 <=> pred = 6
# y = 7.0 <=> pred = 12
# y = 7.0 <=> pred = 8
# y = 7.0 <=> pred = 12
# y = 7.0 <=> pred = 6
# y = 7.0 <=> pred = 6
# y = 8.0 <=> pred = 12
# y = 8.0 <=> pred = 12
# y = 8.0 <=> pred = 12
# y = 8.0 <=> pred = 12
# y = 8.0 <=> pred = 12
# y = 8.0 <=> pred = 12
# y = 8.0 <=> pred = 12
# y = 8.0 <=> pred = 12
# y = 8.0 <=> pred = 12
# y = 8.0 <=> pred = 12
# y = 8.0 <=> pred = 12
# y = 8.0 <=> pred = 9
# y = 8.0 <=> pred = 12
# y = 8.0 <=> pred = 12
# y = 8.0 <=> pred = 12
# y = 8.0 <=> pred = 12
# y = 8.0 <=> pred = 12
# y = 8.0 <=> pred = 12
# y = 8.0 <=> pred = 12
# y = 8.0 <=> pred = 12
# y = 8.0 <=> pred = 6
# y = 8.0 <=> pred = 1
# y = 8.0 <=> pred = 12
# y = 8.0 <=> pred = 12
# y = 8.0 <=> pred = 12
# y = 8.0 <=> pred = 12
# y = 8.0 <=> pred = 12
# y = 8.0 <=> pred = 12
# y = 8.0 <=> pred = 12
# y = 8.0 <=> pred = 12
# y = 8.0 <=> pred = 12
# y = 8.0 <=> pred = 12
# y = 8.0 <=> pred = 12
# y = 8.0 <=> pred = 12
# y = 8.0 <=> pred = 12
# y = 8.0 <=> pred = 12
# y = 8.0 <=> pred = 12
# y = 8.0 <=> pred = 12
# y = 8.0 <=> pred = 12
# y = 8.0 <=> pred = 12
# y = 8.0 <=> pred = 12
# y = 8.0 <=> pred = 12
# y = 8.0 <=> pred = 12
# y = 8.0 <=> pred = 12
# y = 8.0 <=> pred = 12
# y = 8.0 <=> pred = 12
# y = 8.0 <=> pred = 12
# y = 8.0 <=> pred = 12
# y = 8.0 <=> pred = 0
# y = 8.0 <=> pred = 12
# y = 8.0 <=> pred = 0
# y = 8.0 <=> pred = 12
# y = 8.0 <=> pred = 12
# y = 8.0 <=> pred = 12
# y = 8.0 <=> pred = 12
# y = 8.0 <=> pred = 12
# y = 8.0 <=> pred = 12
# y = 8.0 <=> pred = 12
# y = 8.0 <=> pred = 12
# y = 8.0 <=> pred = 12
# y = 8.0 <=> pred = 3
# y = 8.0 <=> pred = 12
# y = 8.0 <=> pred = 12
# y = 8.0 <=> pred = 1
# y = 8.0 <=> pred = 12
# y = 8.0 <=> pred = 12
# y = 8.0 <=> pred = 8
# y = 8.0 <=> pred = 12
# y = 8.0 <=> pred = 12
# y = 8.0 <=> pred = 12
# y = 8.0 <=> pred = 12
# y = 8.0 <=> pred = 12
# y = 8.0 <=> pred = 12
# y = 8.0 <=> pred = 9
# y = 8.0 <=> pred = 12
# y = 8.0 <=> pred = 9
# y = 8.0 <=> pred = 6
# y = 8.0 <=> pred = 8
# y = 8.0 <=> pred = 12
# y = 8.0 <=> pred = 6
# y = 8.0 <=> pred = 9
# y = 8.0 <=> pred = 12
# y = 8.0 <=> pred = 12
# y = 8.0 <=> pred = 12
# y = 8.0 <=> pred = 1
# y = 8.0 <=> pred = 8
# y = 8.0 <=> pred = 8
# y = 8.0 <=> pred = 6
# y = 8.0 <=> pred = 12
# y = 8.0 <=> pred = 12
# y = 8.0 <=> pred = 12
# y = 8.0 <=> pred = 6
# y = 8.0 <=> pred = 12
# y = 8.0 <=> pred = 6
# y = 8.0 <=> pred = 3
# y = 8.0 <=> pred = 12
# y = 8.0 <=> pred = 12
# y = 8.0 <=> pred = 1
# y = 8.0 <=> pred = 6
# y = 8.0 <=> pred = 12
# y = 8.0 <=> pred = 6
# y = 8.0 <=> pred = 6
# y = 8.0 <=> pred = 6
# y = 8.0 <=> pred = 6
# y = 8.0 <=> pred = 6
# y = 8.0 <=> pred = 6
# y = 8.0 <=> pred = 6
# y = 8.0 <=> pred = 6
# y = 8.0 <=> pred = 6
# y = 8.0 <=> pred = 6
# y = 8.0 <=> pred = 9
# y = 8.0 <=> pred = 0
# y = 8.0 <=> pred = 6
# y = 8.0 <=> pred = 6
# y = 8.0 <=> pred = 6
# y = 8.0 <=> pred = 6
# y = 8.0 <=> pred = 6
# y = 8.0 <=> pred = 6
# y = 8.0 <=> pred = 12
# y = 8.0 <=> pred = 6
# y = 8.0 <=> pred = 6
# y = 8.0 <=> pred = 12
# y = 8.0 <=> pred = 1
# y = 8.0 <=> pred = 12
# y = 8.0 <=> pred = 12
# y = 9.0 <=> pred = 12
# y = 9.0 <=> pred = 12
# y = 9.0 <=> pred = 12
# y = 9.0 <=> pred = 12
# y = 9.0 <=> pred = 6
# y = 9.0 <=> pred = 12
# y = 9.0 <=> pred = 12
# y = 9.0 <=> pred = 12
# y = 9.0 <=> pred = 12
# y = 9.0 <=> pred = 12
# y = 9.0 <=> pred = 6
# y = 9.0 <=> pred = 1
# y = 9.0 <=> pred = 12
# y = 9.0 <=> pred = 12
# y = 9.0 <=> pred = 12
# y = 9.0 <=> pred = 12
# y = 9.0 <=> pred = 12
# y = 9.0 <=> pred = 12
# y = 9.0 <=> pred = 12
# y = 9.0 <=> pred = 12
# y = 9.0 <=> pred = 6
# y = 9.0 <=> pred = 12
# y = 9.0 <=> pred = 12
# y = 9.0 <=> pred = 12
# y = 9.0 <=> pred = 12
# y = 9.0 <=> pred = 12
# y = 9.0 <=> pred = 12
# y = 9.0 <=> pred = 12
# y = 9.0 <=> pred = 12
# y = 9.0 <=> pred = 12
# y = 9.0 <=> pred = 12
# y = 9.0 <=> pred = 12
# y = 9.0 <=> pred = 12
# y = 9.0 <=> pred = 12
# y = 9.0 <=> pred = 12
# y = 9.0 <=> pred = 12
# y = 9.0 <=> pred = 12
# y = 9.0 <=> pred = 12
# y = 9.0 <=> pred = 12
# y = 9.0 <=> pred = 12
# y = 9.0 <=> pred = 12
# y = 9.0 <=> pred = 12
# y = 9.0 <=> pred = 12
# y = 9.0 <=> pred = 12
# y = 9.0 <=> pred = 12
# y = 9.0 <=> pred = 12
# y = 9.0 <=> pred = 12
# y = 9.0 <=> pred = 12
# y = 9.0 <=> pred = 12
# y = 9.0 <=> pred = 12
# y = 9.0 <=> pred = 0
# y = 9.0 <=> pred = 0
# y = 9.0 <=> pred = 12
# y = 9.0 <=> pred = 12
# y = 9.0 <=> pred = 12
# y = 9.0 <=> pred = 12
# y = 9.0 <=> pred = 12
# y = 9.0 <=> pred = 12
# y = 9.0 <=> pred = 1
# y = 9.0 <=> pred = 12
# y = 9.0 <=> pred = 12
# y = 9.0 <=> pred = 12
# y = 9.0 <=> pred = 12
# y = 9.0 <=> pred = 12
# y = 9.0 <=> pred = 12
# y = 9.0 <=> pred = 12
# y = 9.0 <=> pred = 12
# y = 9.0 <=> pred = 12
# y = 9.0 <=> pred = 12
# y = 9.0 <=> pred = 12
# y = 9.0 <=> pred = 12
# y = 9.0 <=> pred = 12
# y = 9.0 <=> pred = 12
# y = 9.0 <=> pred = 12
# y = 9.0 <=> pred = 12
# y = 9.0 <=> pred = 12
# y = 9.0 <=> pred = 12
# y = 9.0 <=> pred = 1
# y = 9.0 <=> pred = 12
# y = 9.0 <=> pred = 12
# y = 9.0 <=> pred = 12
# y = 9.0 <=> pred = 12
# y = 9.0 <=> pred = 1
# y = 9.0 <=> pred = 1
# y = 9.0 <=> pred = 1
# y = 9.0 <=> pred = 6
# y = 9.0 <=> pred = 12
# y = 9.0 <=> pred = 12
# y = 9.0 <=> pred = 12
# y = 9.0 <=> pred = 12
# y = 9.0 <=> pred = 12
# y = 9.0 <=> pred = 12
# y = 9.0 <=> pred = 12
# y = 9.0 <=> pred = 6
# y = 9.0 <=> pred = 12
# y = 9.0 <=> pred = 12
# y = 9.0 <=> pred = 12
# y = 9.0 <=> pred = 12
# y = 9.0 <=> pred = 6
# y = 9.0 <=> pred = 6
# y = 9.0 <=> pred = 6
# y = 9.0 <=> pred = 12
# y = 9.0 <=> pred = 6
# y = 9.0 <=> pred = 12
# y = 9.0 <=> pred = 12
# y = 9.0 <=> pred = 12
# y = 9.0 <=> pred = 12
# y = 9.0 <=> pred = 12
# y = 9.0 <=> pred = 12
# y = 9.0 <=> pred = 12
# y = 9.0 <=> pred = 12
# y = 9.0 <=> pred = 12
# y = 9.0 <=> pred = 12
# y = 9.0 <=> pred = 12
# y = 9.0 <=> pred = 12
# y = 9.0 <=> pred = 12
# y = 9.0 <=> pred = 12
# y = 9.0 <=> pred = 6
# y = 9.0 <=> pred = 12
# y = 9.0 <=> pred = 12
# y = 9.0 <=> pred = 6
# y = 9.0 <=> pred = 12
# y = 9.0 <=> pred = 12
# y = 9.0 <=> pred = 6
# y = 9.0 <=> pred = 6
# y = 10.0 <=> pred = 12
# y = 10.0 <=> pred = 12
# y = 10.0 <=> pred = 12
# y = 10.0 <=> pred = 12
# y = 10.0 <=> pred = 1
# y = 10.0 <=> pred = 12
# y = 10.0 <=> pred = 12
# y = 10.0 <=> pred = 12
# y = 10.0 <=> pred = 12
# y = 10.0 <=> pred = 12
# y = 10.0 <=> pred = 12
# y = 10.0 <=> pred = 12
# y = 10.0 <=> pred = 12
# y = 10.0 <=> pred = 12
# y = 10.0 <=> pred = 12
# y = 10.0 <=> pred = 12
# y = 10.0 <=> pred = 12
# y = 10.0 <=> pred = 12
# y = 10.0 <=> pred = 6
# y = 10.0 <=> pred = 12
# y = 10.0 <=> pred = 6
# y = 10.0 <=> pred = 12
# y = 10.0 <=> pred = 9
# y = 10.0 <=> pred = 12
# y = 10.0 <=> pred = 0
# y = 10.0 <=> pred = 12
# y = 10.0 <=> pred = 0
# y = 10.0 <=> pred = 12
# y = 10.0 <=> pred = 12
# y = 10.0 <=> pred = 12
# y = 10.0 <=> pred = 12
# y = 10.0 <=> pred = 12
# y = 10.0 <=> pred = 12
# y = 10.0 <=> pred = 12
# y = 10.0 <=> pred = 12
# y = 10.0 <=> pred = 12
# y = 10.0 <=> pred = 12
# y = 10.0 <=> pred = 12
# y = 10.0 <=> pred = 12
# y = 10.0 <=> pred = 12
# y = 10.0 <=> pred = 12
# y = 10.0 <=> pred = 12
# y = 10.0 <=> pred = 12
# y = 10.0 <=> pred = 12
# y = 10.0 <=> pred = 12
# y = 10.0 <=> pred = 12
# y = 10.0 <=> pred = 12
# y = 10.0 <=> pred = 12
# y = 10.0 <=> pred = 12
# y = 10.0 <=> pred = 12
# y = 10.0 <=> pred = 0
# y = 10.0 <=> pred = 12
# y = 10.0 <=> pred = 12
# y = 10.0 <=> pred = 12
# y = 10.0 <=> pred = 12
# y = 10.0 <=> pred = 12
# y = 10.0 <=> pred = 12
# y = 10.0 <=> pred = 12
# y = 10.0 <=> pred = 3
# y = 10.0 <=> pred = 12
# y = 10.0 <=> pred = 3
# y = 10.0 <=> pred = 12
# y = 10.0 <=> pred = 12
# y = 10.0 <=> pred = 12
# y = 10.0 <=> pred = 9
# y = 10.0 <=> pred = 12
# y = 10.0 <=> pred = 12
# y = 10.0 <=> pred = 12
# y = 10.0 <=> pred = 12
# y = 10.0 <=> pred = 12
# y = 10.0 <=> pred = 12
# y = 10.0 <=> pred = 12
# y = 10.0 <=> pred = 12
# y = 10.0 <=> pred = 12
# y = 10.0 <=> pred = 12
# y = 10.0 <=> pred = 12
# y = 10.0 <=> pred = 6
# y = 10.0 <=> pred = 12
# y = 10.0 <=> pred = 12
# y = 10.0 <=> pred = 12
# y = 10.0 <=> pred = 6
# y = 10.0 <=> pred = 12
# y = 10.0 <=> pred = 12
# y = 10.0 <=> pred = 1
# y = 10.0 <=> pred = 1
# y = 10.0 <=> pred = 6
# y = 10.0 <=> pred = 12
# y = 10.0 <=> pred = 12
# y = 10.0 <=> pred = 12
# y = 10.0 <=> pred = 1
# y = 10.0 <=> pred = 12
# y = 10.0 <=> pred = 6
# y = 10.0 <=> pred = 12
# y = 10.0 <=> pred = 12
# y = 10.0 <=> pred = 3
# y = 10.0 <=> pred = 12
# y = 10.0 <=> pred = 6
# y = 10.0 <=> pred = 12
# y = 10.0 <=> pred = 6
# y = 10.0 <=> pred = 6
# y = 10.0 <=> pred = 6
# y = 10.0 <=> pred = 6
# y = 10.0 <=> pred = 6
# y = 10.0 <=> pred = 12
# y = 10.0 <=> pred = 6
# y = 10.0 <=> pred = 12
# y = 10.0 <=> pred = 12
# y = 10.0 <=> pred = 6
# y = 10.0 <=> pred = 12
# y = 10.0 <=> pred = 12
# y = 10.0 <=> pred = 12
# y = 10.0 <=> pred = 3
# y = 10.0 <=> pred = 6
# y = 10.0 <=> pred = 12
# y = 10.0 <=> pred = 6
# y = 10.0 <=> pred = 6
# y = 10.0 <=> pred = 6
# y = 10.0 <=> pred = 12
# y = 10.0 <=> pred = 12
# y = 10.0 <=> pred = 12
# y = 10.0 <=> pred = 6
# y = 10.0 <=> pred = 6
# y = 10.0 <=> pred = 6
# y = 10.0 <=> pred = 12
# y = 10.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 9
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 6
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 6
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 9
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 1
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 1
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 1
# y = 11.0 <=> pred = 1
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 9
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 9
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 6
# y = 11.0 <=> pred = 8
# y = 11.0 <=> pred = 6
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 6
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 1
# y = 11.0 <=> pred = 6
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 6
# y = 11.0 <=> pred = 9
# y = 11.0 <=> pred = 6
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 6
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 6
# y = 11.0 <=> pred = 6
# y = 11.0 <=> pred = 6
# y = 11.0 <=> pred = 6
# y = 11.0 <=> pred = 6
# y = 11.0 <=> pred = 6
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 6
# y = 11.0 <=> pred = 6
# y = 11.0 <=> pred = 6
# y = 11.0 <=> pred = 6
# y = 11.0 <=> pred = 6
# y = 11.0 <=> pred = 6
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 6
# y = 11.0 <=> pred = 6
# y = 11.0 <=> pred = 6
# y = 11.0 <=> pred = 6
# y = 11.0 <=> pred = 6
# y = 11.0 <=> pred = 6
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 6
# y = 11.0 <=> pred = 6
# y = 11.0 <=> pred = 6
# y = 11.0 <=> pred = 12
# y = 11.0 <=> pred = 6
# y = 11.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 6
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 1
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 6
# y = 12.0 <=> pred = 1
# y = 12.0 <=> pred = 3
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 1
# y = 12.0 <=> pred = 1
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 1
# y = 12.0 <=> pred = 1
# y = 12.0 <=> pred = 1
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 0
# y = 12.0 <=> pred = 9
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 1
# y = 12.0 <=> pred = 1
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 1
# y = 12.0 <=> pred = 9
# y = 12.0 <=> pred = 1
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 6
# y = 12.0 <=> pred = 1
# y = 12.0 <=> pred = 9
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 1
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 9
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 0
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 9
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 6
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 0
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 6
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 6
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 1
# y = 12.0 <=> pred = 9
# y = 12.0 <=> pred = 9
# y = 12.0 <=> pred = 9
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 0
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 6
# y = 12.0 <=> pred = 6
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 1
# y = 12.0 <=> pred = 6
# y = 12.0 <=> pred = 1
# y = 12.0 <=> pred = 0
# y = 12.0 <=> pred = 6
# y = 12.0 <=> pred = 6
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 6
# y = 12.0 <=> pred = 6
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 6
# y = 12.0 <=> pred = 12
# y = 12.0 <=> pred = 6
# y = 12.0 <=> pred = 1
# y = 12.0 <=> pred = 6
# y = 12.0 <=> pred = 6
# y = 12.0 <=> pred = 6
# Test Set Accuracy: 7.753846

# %% [markdown]
# ## save/retrieve the theta values to/from mat file
# after minimizing theta it might be useful to save the values to a mat. The naming of the output files is `nnParameters_xL_y_lmZ.mat` where x is the number of layers and y is the number of nodes in the hidden layer(s) and Z is the chosen lambda.
# > do not forget to set the correct name/path for the output file as pleased

# %%
filename = '../nnParameters/nnParameters_' + str(num_layers) +'L_' + str(hidden_layer_size) + '_lm' + str(lambda_) +'.mat'
matcontent = {"Theta1": Theta1, "Theta2": Theta2}
savemat(filename, matcontent)
# Out:
# (37570013,)

# %%
filename = '../nnParameters/nnParameters_' + str(num_layers) +'L_' + str(hidden_layer_size) + '_lm' + str(lambda_) +'.mat'
Thetas = loadmat(filename)
Theta1, Theta2 = Thetas['Theta1'], Thetas['Theta2']

# %% [markdown]
# ## Bias/Variance diagnosing
# In this section bias/variance is diagnosed by varying the `hidden layer size` as well as the `lambda` parameter. The error values are saved to a CSV named `diagnosing.csv`

# %%
# we initialize the minimize function options
options = {'maxiter':25, 'disp':True}

num_layers = 3
input_layer_size = X.shape[1]
num_labels = y.shape[1]

#list of lambda values to be tested
lambda_list = [0, 1, 10]

#hidden layer size list
HLS_list = [7500]

# %%
error_train = np.zeros((len(HLS_list), len(lambda_list)))
error_test = np.zeros((len(HLS_list), len(lambda_list)))

#with open('diagnosing3L.csv', 'a', newline='') as csvfile:
#    fieldnames = ['HLS', 'lambda', 'trainError', 'testError']
#    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
#    writer.writeheader()
    
i = 0
for HLS in HLS_list:
    j = 0

    eps1 = math.sqrt(6)/math.sqrt(input_layer_size + HLS)
    eps2 = math.sqrt(6)/math.sqrt(HLS + num_labels)

    initial_Theta1 = cu.randInitializeWeights(input_layer_size, HLS, eps1)
    initial_Theta2 = cu.randInitializeWeights(HLS, num_labels, eps2)

    initial_nn_params_start = np.concatenate([initial_Theta1.ravel(), initial_Theta2.ravel()], axis=0)

    for lambda_val in lambda_list:
        filename = '../nnParameters/nnParameters_' + str(num_layers) +'L_' + str(HLS) + '_lm' + str(lambda_val) +'.mat'
        if os.path.exists(filename):
            print("loading existing thetas")
            Thetas = loadmat(filename)
            Theta1, Theta2 = Thetas['Theta1'], Thetas['Theta2']
            initial_nn_params = np.concatenate([Theta1.ravel(), Theta2.ravel()], axis=0)
        else:
            initial_nn_params =  initial_nn_params_start
        
        #creating a lambda function for the cost function
        costFunction = lambda p: cu.nnCostFunction(p, input_layer_size,
                                                HLS,
                                                num_labels, X, y, lambda_val)

        print("running optimize.minimize for HLS = " + str(HLS) + " and lambda = " + str(lambda_val))
        start = timer()

        # execute the optimization function
        res = optimize.minimize(costFunction,
                                initial_nn_params,
                                jac=True,
                                method='TNC',
                                options=options)

        print("done optimizing, run time was " + str(timer()-start))
        #get the solution parameters
        nn_params = res.x

        #reshape nn_params to retrieve the seperate theta matrixes 
        Theta1 , Theta2 = cu.retrieveThetas(nn_params, input_layer_size, HLS, num_labels)

        #calculate error on training set
        error_train[i,j], _ = cu.nnCostFunction(nn_params, input_layer_size, HLS, num_labels, X, y, lambda_=0)
        #calculate error on test set
        error_test[i,j], _ = cu.nnCostFunction(nn_params, input_layer_size, HLS, num_labels, X_test, y_test, lambda_=0)
        print("train error = " + str(error_train[i,j]) + ' and test error = ' + str(error_test[i,j]))
  
        #print('saving theta values to MAT file')
        print("writing" + filename)
        matcontent = {"Theta1": Theta1, "Theta2": Theta2}
        savemat(filename, matcontent)

        #set j for next loop
        j += 1
    #set i for next loop
    i += 1
# Out:
# loading existing thetas
# running optimize.minimize for HLS = 7500 and lambda = 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-7872717f6043> in <module>
#      42                                 jac=True,
#      43                                 method='TNC',
# ---> 44                                 options=options)
#      45
#      46         print("done optimizing, run time was " + str(timer()-start))
#
# c:\users\lenne\appdata\local\programs\python\python36\lib\site-packages\scipy\optimize\_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     619     elif meth == 'tnc':
#     620         return _minimize_tnc(fun, x0, args, jac, bounds, callback=callback,
# --> 621                              **options)
#     622     elif meth == 'cobyla':
#     623         return _minimize_cobyla(fun, x0, args, constraints, **options)
#
# c:\users\lenne\appdata\local\programs\python\python36\lib\site-packages\scipy\optimize\tnc.py in _minimize_tnc(fun, x0, args, jac, bounds, eps, scale, offset, mesg_num, maxCGit, maxiter, eta, stepmx, accuracy, minfev, ftol, xtol, gtol, rescale, disp, callback, finite_diff_rel_step, maxfun, **unknown_options)
#     415                                         offset, messages, maxCGit, maxfun,
#     416                                         eta, stepmx, accuracy, fmin, ftol,
# --> 417                                         xtol, pgtol, rescale, callback)
#     418
#     419     funv, jacv = func_and_grad(x)
#
# c:\users\lenne\appdata\local\programs\python\python36\lib\site-packages\scipy\optimize\_differentiable_functions.py in fun_and_grad(self, x)
#     198         if not np.array_equal(x, self.x):
#     199             self._update_x_impl(x)
# --> 200         self._update_fun()
#     201         self._update_grad()
#     202         return self.f, self.g
#
# c:\users\lenne\appdata\local\programs\python\python36\lib\site-packages\scipy\optimize\_differentiable_functions.py in _update_fun(self)
#     164     def _update_fun(self):
#     165         if not self.f_updated:
# --> 166             self._update_fun_impl()
#     167             self.f_updated = True
#     168
#
# c:\users\lenne\appdata\local\programs\python\python36\lib\site-packages\scipy\optimize\_differentiable_functions.py in update_fun()
#      71
#      72         def update_fun():
# ---> 73             self.f = fun_wrapped(self.x)
#      74
#      75         self._update_fun_impl = update_fun
#
# c:\users\lenne\appdata\local\programs\python\python36\lib\site-packages\scipy\optimize\_differentiable_functions.py in fun_wrapped(x)
#      68         def fun_wrapped(x):
#      69             self.nfev += 1
# ---> 70             return fun(x, *args)
#      71
#      72         def update_fun():
#
# c:\users\lenne\appdata\local\programs\python\python36\lib\site-packages\scipy\optimize\optimize.py in __call__(self, x, *args)
#      72     def __call__(self, x, *args):
#      73         """ returns the the function value """
# ---> 74         self._compute_if_needed(x, *args)
#      75         return self._value
#      76
#
# c:\users\lenne\appdata\local\programs\python\python36\lib\site-packages\scipy\optimize\optimize.py in _compute_if_needed(self, x, *args)
#      66         if not np.all(x == self.x) or self._value is None or self.jac is None:
#      67             self.x = np.asarray(x).copy()
# ---> 68             fg = self.fun(x, *args)
#      69             self.jac = fg[1]
#      70             self._value = fg[0]
#
# <ipython-input-5-7872717f6043> in <lambda>(p)
#      32         costFunction = lambda p: cu.nnCostFunction(p, input_layer_size,
#      33                                                 HLS,
# ---> 34                                                 num_labels, X, y, lambda_val)
#      35
#      36         print("running optimize.minimize for HLS = " + str(HLS) + " and lambda = " + str(lambda_val))
#
# C:\devWorks\MACH\MicroPCBs\Mach_Project\customUtils.py in nnCostFunction(nn_params, input_layer_size, hidden_layer_size, num_labels, X, y, lambda_)
#     127     a1 = np.concatenate([np.ones((m,1)),X], axis=1)
#     128
# --> 129     z2 = np.dot(a1, Theta1.T)
#     130     a2 = utils.sigmoid(z2)
#     131     a2 = np.concatenate([np.ones((a2.shape[0], 1)), a2], axis=1)
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
i = 0
for HLS in HLS_list:
    j = 0
    for lambda_val in lambda_list:
        filename = '../nnParameters/nnParameters_' + str(num_layers) +'L_' + str(HLS) + '_lm' + str(lambda_val) +'.mat'
        #Theta1, Theta2 = cu.thetasFromCSV(filePath, (HLS,(X.shape[1]+1)), (y.shape[1],(HLS+1))) 
        Thetas = loadmat(filename)
        Theta1, Theta2 = Thetas['Theta1'], Thetas['Theta2']
        
        print('prediction accuracy for lambda = ' + str(lambda_val) + ' and HLS = ' + str(HLS))
        
        pred = utils.predict(Theta1, Theta2, X)

        y_vec = np.zeros(y.shape[0])
        for j in range(0,y.shape[0]):
            y_vec[j] = np.where(y[j,:] == 1)[0][0]

        print('Training Set Accuracy: %f' % (np.mean(pred == y_vec) * 100))
        
        pred_test = utils.predict(Theta1, Theta2, X_test)
        y_test_vec = np.zeros(y_test.shape[0])

        for j in range(y_test_vec.shape[0]):
            y_test_vec[j] = np.where(y_test[j,:] == 1)[0][0]

        print('Test Set Accuracy: %f' % (np.mean(pred_test == y_test_vec) * 100))
# Out:
# prediction accuracy for lambda = 0 and HLS = 7500
# Training Set Accuracy: 77.015385
# Test Set Accuracy: 59.200000
# prediction accuracy for lambda = 1 and HLS = 7500
# Training Set Accuracy: 84.015385
# Test Set Accuracy: 66.276923
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\users\lenne\appdata\local\programs\python\python36\lib\site-packages\scipy\io\matlab\mio.py in _open_file(file_like, appendmat, mode)
#      38     try:
# ---> 39         return open(file_like, mode), True
#      40     except IOError:
#
# FileNotFoundError: [Errno 2] No such file or directory: '../nnParameters/nnParameters_3L_7500_lm10.mat'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-3ac23c0cd59e> in <module>
#       5         filename = '../nnParameters/nnParameters_' + str(num_layers) +'L_' + str(HLS) + '_lm' + str(lambda_val) +'.mat'
#       6         #Theta1, Theta2 = cu.thetasFromCSV(filePath, (HLS,(X.shape[1]+1)), (y.shape[1],(HLS+1)))
# ----> 7         Thetas = loadmat(filename)
#       8         Theta1, Theta2 = Thetas['Theta1'], Thetas['Theta2']
#       9
#
# c:\users\lenne\appdata\local\programs\python\python36\lib\site-packages\scipy\io\matlab\mio.py in loadmat(file_name, mdict, appendmat, **kwargs)
#     220     """
#     221     variable_names = kwargs.pop('variable_names', None)
# --> 222     with _open_file_context(file_name, appendmat) as f:
#     223         MR, _ = mat_reader_factory(f, **kwargs)
#     224         matfile_dict = MR.get_variables(variable_names)
#
# c:\users\lenne\appdata\local\programs\python\python36\lib\contextlib.py in __enter__(self)
#      79     def __enter__(self):
#      80         try:
# ---> 81             return next(self.gen)
#      82         except StopIteration:
#      83             raise RuntimeError("generator didn't yield") from None
#
# c:\users\lenne\appdata\local\programs\python\python36\lib\site-packages\scipy\io\matlab\mio.py in _open_file_context(file_like, appendmat, mode)
#      15 @contextmanager
#      16 def _open_file_context(file_like, appendmat, mode='rb'):
# ---> 17     f, opened = _open_file(file_like, appendmat, mode)
#      18     try:
#      19         yield f
#
# c:\users\lenne\appdata\local\programs\python\python36\lib\site-packages\scipy\io\matlab\mio.py in _open_file(file_like, appendmat, mode)
#      43             if appendmat and not file_like.endswith('.mat'):
#      44                 file_like += '.mat'
# ---> 45             return open(file_like, mode), True
#      46         else:
#      47             raise IOError('Reader needs file name or open file-like object')
#
# FileNotFoundError: [Errno 2] No such file or directory: '../nnParameters/nnParameters_3L_7500_lm10.mat'

# %%
for HLS in HLS_list:
    for lambda_val in lambda_list: 
        filePath = '../nnParameters/nnParameters_' + str(num_layers) +'L_' + str(HLS) + '_lm' + str(lambda_val) +'.csv'
        if os.path.exists(filePath):
            print("reading" + filePath)
            Theta1, Theta2 = cu.thetasFromCSV(filePath, (HLS,(X.shape[1]+1)), (y.shape[1],(HLS+1)))

            filename = '../nnParameters/nnParameters_' + str(num_layers) +'L_' + str(HLS) + '_lm' + str(lambda_val) +'.mat'
            
            print("writing" + filename)
            matcontent = {"Theta1": Theta1, "Theta2": Theta2}
            savemat(filename, matcontent)
# Out:
# reading../nnParameters/nnParameters_3L_7500_lm1.csv
# writing../nnParameters/nnParameters_3L_7500_lm1.mat
# reading../nnParameters/nnParameters_3L_10000_lm1.csv
# writing../nnParameters/nnParameters_3L_10000_lm1.mat
# reading../nnParameters/nnParameters_3L_10000_lm3.csv
# writing../nnParameters/nnParameters_3L_10000_lm3.mat

# %% [markdown]
# ### evaluating the trained models
# In this section the trained models are evaluated (cost calculated without regularisation) for the training set as well as the test set. These values are saved in a csv file.

# %%
i = 0
for HLS in HLS_list:
    j = 0
    for lambda_val in lambda_list:
        filename = '../nnParameters/nnParameters_' + str(num_layers) +'L_' + str(HLS) + '_lm' + str(lambda_val) +'.mat'
        if os.path.exists(filename):
            Thetas = loadmat(filename)
            Theta1, Theta2 = Thetas['Theta1'], Thetas['Theta2']

            nn_params = np.concatenate([Theta1.ravel(), Theta2.ravel()])
            
            #calculate error on training set
            error_train, _ = cu.nnCostFunction(nn_params, input_layer_size, HLS, num_labels, X, y, lambda_=0)
            #calculate error on test set
            error_test, _ = cu.nnCostFunction(nn_params, input_layer_size, HLS, num_labels, X_test, y_test, lambda_=0)
            print(" writing train error = " + str(error_train) + ' and test error = '
                  + str(error_test) + ' for HLS ' + str(HLS) + ' and lambda ' + str(lambda_val))

            with open('diagnosing3L.csv', 'a', newline='') as csvfile:
                fieldnames = ['HLS', 'lambda', 'trainError', 'testError']
                writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
                #save the values to CSV
                writer.writerow({'HLS': HLS, 'lambda': lambda_val, 'trainError': error_train, 'testError': error_test})
# Out:
#  writing train error = 3.505138310985124 and test error = 3.5085853891197702 for HLS 250 and lambda 0
#  writing train error = 3.5117333141453315 and test error = 3.512543843232681 for HLS 250 and lambda 0.01
#  writing train error = 3.5143863118196355 and test error = 3.519529638556072 for HLS 250 and lambda 0.1
#  writing train error = 3.526818949525107 and test error = 3.5271079390268874 for HLS 250 and lambda 1
#  writing train error = 3.6102636299444106 and test error = 3.608507422379693 for HLS 250 and lambda 10
#  writing train error = 3.391192858471299 and test error = 3.4147491866821484 for HLS 1000 and lambda 0
#  writing train error = 3.3454815829400673 and test error = 3.3809843867705274 for HLS 1000 and lambda 0.01
#  writing train error = 3.3459068783672525 and test error = 3.3767797014725622 for HLS 1000 and lambda 0.1
#  writing train error = 3.3512362893987206 and test error = 3.3820059787567254 for HLS 1000 and lambda 1
#  writing train error = 3.4383815189090394 and test error = 3.46148829089757 for HLS 1000 and lambda 10
#  writing train error = 2.9417340835982615 and test error = 3.070211701925522 for HLS 2500 and lambda 0
#  writing train error = 3.188963527398958 and test error = 3.245334779455638 for HLS 2500 and lambda 0.01
#  writing train error = 3.2368020586966324 and test error = 3.286634103683041 for HLS 2500 and lambda 0.1
#  writing train error = 3.100520212463069 and test error = 3.1689842731706728 for HLS 2500 and lambda 1
#  writing train error = 3.000276019039045 and test error = 3.0873436760103585 for HLS 2500 and lambda 10
#  writing train error = 2.5017658845458066 and test error = 2.686816859966094 for HLS 5000 and lambda 0
#  writing train error = 2.6325401553523626 and test error = 2.7869727777904587 for HLS 5000 and lambda 0.01
#  writing train error = 2.5186531517340263 and test error = 2.6784992778614503 for HLS 5000 and lambda 0.1
#  writing train error = 2.6288458931529526 and test error = 2.7688098330121016 for HLS 5000 and lambda 1
#  writing train error = 2.6967362089042863 and test error = 2.862367366937259 for HLS 5000 and lambda 10
#  writing train error = 2.4807630447995415 and test error = 2.675096625993771 for HLS 7500 and lambda 0
#  writing train error = 2.2771014361983792 and test error = 2.510829534199542 for HLS 7500 and lambda 1
#  writing train error = 2.1132457399329585 and test error = 2.3739211460806526 for HLS 10000 and lambda 0
#  writing train error = 2.1497211073410676 and test error = 2.4139690778082747 for HLS 10000 and lambda 1

# %% [markdown]
# ### plotting the evaluation data
# #### error vs amount of parameters (HLS) plot
# train error and test error are plotted for a chosen lambda with varying hidden layer size.

# %%
train_error = []
test_error = []
HLS_array = []

with open('diagnosing3L.csv', newline='') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        if float(row['lambda']) == 0:
            train_error.append(float(row['trainError']))
            test_error.append(float(row['testError']))
            HLS_array.append(int(row['HLS']))

pyplot.plot(HLS_array, train_error, 'b')
pyplot.plot(HLS_array, test_error, 'r')
pyplot.axis([min(HLS_array), max(HLS_array), min(min(train_error),min(test_error)), max(max(train_error),max(test_error))])
pyplot.legend(["train", "test"])
pyplot.show()

# %% [markdown]
# #### error vs lambda plot
# train and test error are plotted vs lambda for a given hidden layer size. Be sure to set the desired HLS for the plot.

# %%
train_error = []
test_error = []
lambda_array = []

with open('diagnosing3L.csv', newline='') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        if int(row['HLS']) == 5000 and float(row['lambda']) != 0:
            train_error.append(float(row['trainError']))
            test_error.append(float(row['testError']))
            lambda_array.append(float(row['lambda']))

pyplot.plot(lambda_array, train_error, 'b')
pyplot.plot(lambda_array, test_error, 'r')
pyplot.axis([min(lambda_array), max(lambda_array), min(min(train_error),min(test_error)), max(max(train_error),max(test_error))])
pyplot.xscale('log')
pyplot.legend(["train", "test"])
pyplot.show()
